# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Salaries.csv")

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  cheif  count
# 0  2011    NaN  San Francisco     NaN      0      0
# 1  2011    NaN  San Francisco     NaN      0      0
# 2  2011    NaN  San Francisco     NaN      0      0
# 3  2011    NaN  San Francisco     NaN      0      0
# 4  2011    NaN  San Francisco     NaN      0      1

# %%
df.info()

# %%
df2 = df["BasePay"].mean()
print(df2)
# Out:
# 66325.4488404877

# %%
print(df['OvertimePay'].max())
# Out:
# 245131.88

# %%
x=df[df['EmployeeName']=='JOSEPH DRISCOLL']
x
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status  cheif  count
# 24  San Francisco     NaN      0      0

# %%
df['JobTitle'].loc[24]
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %%
x['BasePay']+x['OtherPay']+x['OvertimePay']
# Out:
# 24    270324.91
# dtype: float64

# %%
df[df['TotalPayBenefits']== df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status  cheif  count  title_len
# 0  2011    NaN  San Francisco     NaN      0      0         46

# %%
df[df['TotalPayBenefits']== df['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status  cheif  count  title_len
# 148653  San Francisco     NaN      0      0         26

# %%
df.groupby(['Year'])['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
df['JobTitle'].value_counts().nlargest(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
(df[df['Year']==2013]['JobTitle'].value_counts() == 1).sum()
# Out:
# 202

# %%
df['title_len'] = df['JobTitle'].apply(len)
df[['title_len','TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
df[df['TotalPayBenefits']== df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status  cheif  count  title_len
# 0  2011    NaN  San Francisco     NaN      0      0         46
